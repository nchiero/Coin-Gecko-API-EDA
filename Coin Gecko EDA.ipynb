# %% [markdown]
# # 1. Bitcoin and Cryptocurrencies:

# %% [markdown]
# Since the launch of Bitcoin in 2008, hundreds of similar projects based on the blockchain technology have emerged. We call these cryptocurrencies (also coins or cryptos in the Internet slang). Some are extremely valuable nowadays, and others may have the potential to become extremely valuable in the future. In fact, on the 6th of December of 2021, Bitcoin has a market capitalization around $1 Trillion.

# %% [markdown]
# The data I will be using for my cryptocurrency exploratory data analysis is coming directly from the Coin-Gecko API. The link to the API documentation can be found here https://www.coingecko.com/en/api/documentation. I found working with the API a breeze and using the python API wrapper made setting parameters simple. The only downside is each call is limited to 250 coins, but I found a way around that to get a list of 1000 coins.

# %% [markdown]
# ### Setting up enviroment

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Connecting to Coin Gecko API

# %% [markdown]
# Single Coin Parameters

# %%
cg.get_price(ids='bitcoin', vs_currencies='usd')
# Out:
# {'bitcoin': {'usd': 48471}}

# %% [markdown]
# JSON file received after pinging the API

# %%
coin_market=cg.get_coins_markets(vs_currency='usd')

# %%
coin_market
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 48471,
#   'market_cap': 916676439150,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1018707947174,
#   'total_volume': 28270596038,
#   'high_24h': 50308,
#   'low_24h': 47441,
#   'price_change_24h': -1392.410487605688,
#   'price_change_percentage_24h': -2.79244,
#   'market_cap_change_24h': -26726927398.193726,
#   'market_cap_change_percentage_24h': -2.83303,
#   'circulating_supply': 18896687.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -29.74138,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 71439.03206,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:00.060Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#   'current_price': 4155.24,
#   'market_cap': 493586415595,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': None,
#   'total_volume': 24070832561,
#   'high_24h': 4407.44,
#   'low_24h': 4089.69,
#   'price_change_24h': -239.671338073566,
#   'price_change_percentage_24h': -5.45338,
#   'market_cap_change_24h': -28148252827.60443,
#   'market_cap_change_percentage_24h': -5.39513,
#   'circulating_supply': 118675909.4365,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -14.74185,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 960481.45801,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 113.69423777357225,
#    'currency': 'btc',
#    'percentage': 11369.423777357226},
#   'last_updated': '2021-12-10T03:24:18.385Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'Binance Coin',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/binance-coin-logo.png?1547034615',
#   'current_price': 579.28,
#   'market_cap': 97595424357,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 97595424357,
#   'total_volume': 2007815364,
#   'high_24h': 607.33,
#   'low_24h': 568.79,
#   'price_change_24h': -24.4365950856,
#   'price_change_percentage_24h': -4.04771,
#   'market_cap_change_24h': -4028554357.707184,
#   'market_cap_change_percentage_24h': -3.96418,
#   'circulating_supply': 168137035.9,
#   'total_supply': 168137035.9,
#   'max_supply': 168137035.9,
#   'ath': 686.31,
#   'ath_change_percentage': -15.42898,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1457584.69949,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:40.240Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether-logo.png?1598003707',
#   'current_price': 0.999768,
#   'market_cap': 77180934430,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': None,
#   'total_volume': 60269165356,
#   'high_24h': 1.01,
#   'low_24h': 0.990266,
#   'price_change_24h': -0.001081067252,
#   'price_change_percentage_24h': -0.10801,
#   'market_cap_change_24h': -212511171.65296936,
#   'market_cap_change_percentage_24h': -0.27459,
#   'circulating_supply': 77183275316.4391,
#   'total_supply': 77183275316.4391,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.42195,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.66078,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:31.902Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/Solana.jpg?1635329178',
#   'current_price': 180.92,
#   'market_cap': 55705620939,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': None,
#   'total_volume': 1809924235,
#   'high_24h': 191.93,
#   'low_24h': 179.33,
#   'price_change_24h': -9.32791503101,
#   'price_change_percentage_24h': -4.90293,
#   'market_cap_change_24h': -2859777508.5854645,
#   'market_cap_change_percentage_24h': -4.88305,
#   'circulating_supply': 307347322.141825,
#   'total_supply': 508180963.57,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -30.27882,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 36091.33735,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:53.168Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1547034860',
#   'current_price': 1.3,
#   'market_cap': 41771155691,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 58619070214,
#   'total_volume': 1473585779,
#   'high_24h': 1.39,
#   'low_24h': 1.29,
#   'price_change_24h': -0.073393976189,
#   'price_change_percentage_24h': -5.33882,
#   'market_cap_change_24h': -2269610515.1697083,
#   'market_cap_change_percentage_24h': -5.15343,
#   'circulating_supply': 32066390668.4135,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -57.80099,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 6666.02673,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:50.113Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USD Coin',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/USD_Coin_icon.png?1547042389',
#   'current_price': 0.9984,
#   'market_cap': 40999068016,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': None,
#   'total_volume': 4574217903,
#   'high_24h': 1.01,
#   'low_24h': 0.989871,
#   'price_change_24h': 0.00042319,
#   'price_change_percentage_24h': 0.0424,
#   'market_cap_change_24h': 147846673,
#   'market_cap_change_percentage_24h': 0.36191,
#   'circulating_supply': 41055983892.5873,
#   'total_supply': 41028251977.9299,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.84536,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.891848,
#   'atl_change_percentage': 11.9713,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:45.240Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1605778731',
#   'current_price': 0.854199,
#   'market_cap': 40456750111,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 85627652234,
#   'total_volume': 4591964152,
#   'high_24h': 0.92674,
#   'low_24h': 0.838543,
#   'price_change_24h': -0.001351013442,
#   'price_change_percentage_24h': -0.15791,
#   'market_cap_change_24h': 250828872,
#   'market_cap_change_percentage_24h': 0.62386,
#   'circulating_supply': 47247295769.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -74.80391,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 31776.79245,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:47.719Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/aJGBjJFU_400x400.jpg?1597804776',
#   'current_price': 27.39,
#   'market_cap': 29163312626,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': None,
#   'total_volume': 1063975140,
#   'high_24h': 29.15,
#   'low_24h': 26.94,
#   'price_change_24h': -1.62295272054,
#   'price_change_percentage_24h': -5.59386,
#   'market_cap_change_24h': -1665555827.9982948,
#   'market_cap_change_percentage_24h': -5.40259,
#   'circulating_supply': 1063614808.50772,
#   'total_supply': 1144563943.34462,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -50.12812,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 916.51391,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:00.323Z'},
#  {'id': 'terra-luna',
#   'symbol': 'luna',
#   'name': 'Terra',
#   'image': 'https://assets.coingecko.com/coins/images/8284/large/luna1557227471663.png?1567147072',
#   'current_price': 68.32,
#   'market_cap': 25940106530,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 68311734726,
#   'total_volume': 2764327768,
#   'high_24h': 76.23,
#   'low_24h': 65.87,
#   'price_change_24h': -6.107052438025,
#   'price_change_percentage_24h': -8.20519,
#   'market_cap_change_24h': -2373579814.21574,
#   'market_cap_change_percentage_24h': -8.38315,
#   'circulating_supply': 379731339.485357,
#   'total_supply': 852777341.691715,
#   'max_supply': 1000000000.0,
#   'ath': 77.73,
#   'ath_change_percentage': -12.1169,
#   'ath_date': '2021-12-05T09:49:05.708Z',
#   'atl': 0.121798,
#   'atl_change_percentage': 55986.0136,
#   'atl_date': '2020-03-18T17:03:01.083Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:08.168Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1547792256',
#   'current_price': 0.17141,
#   'market_cap': 22723012582,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': None,
#   'total_volume': 911733804,
#   'high_24h': 0.179059,
#   'low_24h': 0.170035,
#   'price_change_24h': -0.006020703661,
#   'price_change_percentage_24h': -3.39327,
#   'market_cap_change_24h': -785710539.0874023,
#   'market_cap_change_percentage_24h': -3.34221,
#   'circulating_supply': 132453937678.729,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -76.55014,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 197306.96957,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:25.964Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'AVAX',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/coin-round-red.png?1604021818',
#   'current_price': 89.29,
#   'market_cap': 21719847601,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 64404257328,
#   'total_volume': 900201976,
#   'high_24h': 93.99,
#   'low_24h': 83.59,
#   'price_change_24h': -3.327623687692,
#   'price_change_percentage_24h': -3.59293,
#   'market_cap_change_24h': -733741969.4460106,
#   'market_cap_change_percentage_24h': -3.26782,
#   'circulating_supply': 242814542.413209,
#   'total_supply': 377752194.4695483,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -38.3561,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 3090.20691,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:29.641Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1622619446',
#   'current_price': 3.517e-05,
#   'market_cap': 19349255586,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': None,
#   'total_volume': 1035244076,
#   'high_24h': 3.723e-05,
#   'low_24h': 3.447e-05,
#   'price_change_24h': -1.487893e-06,
#   'price_change_percentage_24h': -4.05852,
#   'market_cap_change_24h': -809780500.2741241,
#   'market_cap_change_percentage_24h': -4.01696,
#   'circulating_supply': 549151365036167.2,
#   'total_supply': 1000000000000000.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -59.14718,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6e-11,
#   'atl_change_percentage': 62445446.6679,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:31.790Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/matic-token-icon.png?1624446912',
#   'current_price': 2.23,
#   'market_cap': 15347565285,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 22330584249,
#   'total_volume': 3066923546,
#   'high_24h': 2.36,
#   'low_24h': 2.09,
#   'price_change_24h': -0.121461481901,
#   'price_change_percentage_24h': -5.16649,
#   'market_cap_change_24h': -711129279.7321758,
#   'market_cap_change_percentage_24h': -4.42831,
#   'circulating_supply': 6872890164.27,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.62,
#   'ath_change_percentage': -14.78269,
#   'ath_date': '2021-05-18T19:38:18.813Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 70931.38626,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 846.713829246454,
#    'currency': 'usd',
#    'percentage': 84671.3829246454},
#   'last_updated': '2021-12-10T03:25:20.032Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Crypto.com Coin',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cypto.png?1547043960',
#   'current_price': 0.580599,
#   'market_cap': 14681176588,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': None,
#   'total_volume': 303167848,
#   'high_24h': 0.62135,
#   'low_24h': 0.56164,
#   'price_change_24h': -0.02996895153,
#   'price_change_percentage_24h': -4.90837,
#   'market_cap_change_24h': -717686004.6198006,
#   'market_cap_change_percentage_24h': -4.66064,
#   'circulating_supply': 25263013692.0,
#   'total_supply': 30263013692.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -39.80434,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 4694.98775,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:30.814Z'},
#  {'id': 'binance-usd',
#   'symbol': 'busd',
#   'name': 'Binance USD',
#   'image': 'https://assets.coingecko.com/coins/images/9576/large/BUSD.png?1568947766',
#   'current_price': 0.998786,
#   'market_cap': 13757141766,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': None,
#   'total_volume': 4857128074,
#   'high_24h': 1.01,
#   'low_24h': 0.991059,
#   'price_change_24h': -0.001023680293,
#   'price_change_percentage_24h': -0.10239,
#   'market_cap_change_24h': 103506250,
#   'market_cap_change_percentage_24h': 0.75809,
#   'circulating_supply': 13769119817.28,
#   'total_supply': 13769119817.28,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.43557,
#   'ath_date': '2020-03-13T02:35:42.953Z',
#   'atl': 0.901127,
#   'atl_change_percentage': 10.87559,
#   'atl_date': '2021-05-19T13:04:37.445Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:36.618Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1548822744',
#   'current_price': 48427,
#   'market_cap': 12438248252,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 12438248252,
#   'total_volume': 402406664,
#   'high_24h': 50132,
#   'low_24h': 47403,
#   'price_change_24h': -1502.852366710264,
#   'price_change_percentage_24h': -3.0099,
#   'market_cap_change_24h': -377819168.5180435,
#   'market_cap_change_percentage_24h': -2.94801,
#   'circulating_supply': 256689.84405604,
#   'total_supply': 256689.84405604,
#   'max_supply': 256689.84405604,
#   'ath': 70643,
#   'ath_change_percentage': -31.40714,
#   'ath_date': '2021-11-10T14:40:19.650Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 1443.6017,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:50.214Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1547033580',
#   'current_price': 153.89,
#   'market_cap': 10653246943,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 12940097967,
#   'total_volume': 1228021211,
#   'high_24h': 162.71,
#   'low_24h': 152.04,
#   'price_change_24h': -7.222072561778,
#   'price_change_percentage_24h': -4.4827,
#   'market_cap_change_24h': -497870953.81028175,
#   'market_cap_change_percentage_24h': -4.46476,
#   'circulating_supply': 69155020.7334713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -62.4512,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 13308.94375,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:52.815Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'image': 'https://assets.coingecko.com/coins/images/4380/large/download.png?1547039725',
#   'current_price': 1.56,
#   'market_cap': 9888538869,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 15667103746,
#   'total_volume': 266033236,
#   'high_24h': 1.67,
#   'low_24h': 1.55,
#   'price_change_24h': -0.086636367697,
#   'price_change_percentage_24h': -5.24599,
#   'market_cap_change_24h': -534096851.04170036,
#   'market_cap_change_percentage_24h': -5.12439,
#   'circulating_supply': 6311657233.30534,
#   'total_supply': 6763725735.28994,
#   'max_supply': 10000000000.0,
#   'ath': 3.56,
#   'ath_change_percentage': -56.00555,
#   'ath_date': '2019-06-20T14:51:19.480Z',
#   'atl': 0.105336,
#   'atl_change_percentage': 1387.35254,
#   'atl_date': '2020-03-13T02:20:48.438Z',
#   'roi': {'times': -0.3479820384950979,
#    'currency': 'usd',
#    'percentage': -34.79820384950979},
#   'last_updated': '2021-12-10T03:24:36.279Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1547034700',
#   'current_price': 20.36,
#   'market_cap': 9530691160,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 20407914742,
#   'total_volume': 1143928923,
#   'high_24h': 22.14,
#   'low_24h': 20.36,
#   'price_change_24h': -1.474992815658,
#   'price_change_percentage_24h': -6.75459,
#   'market_cap_change_24h': -661130433.5259113,
#   'market_cap_change_percentage_24h': -6.48687,
#   'circulating_supply': 467009553.9174637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -61.27265,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 13672.1393,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:53.407Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1547035066',
#   'current_price': 0.09011,
#   'market_cap': 9188662195,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': None,
#   'total_volume': 1102851598,
#   'high_24h': 0.092401,
#   'low_24h': 0.088861,
#   'price_change_24h': -0.001008474741,
#   'price_change_percentage_24h': -1.10677,
#   'market_cap_change_24h': -94263940.18553543,
#   'market_cap_change_percentage_24h': -1.01546,
#   'circulating_supply': 101890696406.9,
#   'total_supply': 101900409184.273,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -61.05873,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 4899.95704,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 46.42623462081214,
#    'currency': 'usd',
#    'percentage': 4642.623462081214},
#   'last_updated': '2021-12-10T03:25:32.441Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/4943.png?1636636734',
#   'current_price': 0.998743,
#   'market_cap': 8918787138,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 8918787138,
#   'total_volume': 775119921,
#   'high_24h': 1.01,
#   'low_24h': 0.984305,
#   'price_change_24h': 0.00081881,
#   'price_change_percentage_24h': 0.08205,
#   'market_cap_change_24h': 9080810,
#   'market_cap_change_percentage_24h': 0.10192,
#   'circulating_supply': 8926455641.18045,
#   'total_supply': 8926455641.18045,
#   'max_supply': 8926455641.18045,
#   'ath': 1.22,
#   'ath_change_percentage': -18.03134,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.903243,
#   'atl_change_percentage': 10.61706,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:32.978Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1594689492',
#   'current_price': 455.5,
#   'market_cap': 8626102037,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 9572835580,
#   'total_volume': 2296002474,
#   'high_24h': 469.22,
#   'low_24h': 449.84,
#   'price_change_24h': -10.523475727351,
#   'price_change_percentage_24h': -2.25812,
#   'market_cap_change_24h': -186304416.6951065,
#   'market_cap_change_percentage_24h': -2.11412,
#   'circulating_supply': 18923143.6466526,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -87.95903,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 492.51385,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:26:05.305Z'},
#  {'id': 'terrausd',
#   'symbol': 'ust',
#   'name': 'TerraUSD',
#   'image': 'https://assets.coingecko.com/coins/images/12681/large/UST.png?1601612407',
#   'current_price': 1.0,
#   'market_cap': 8567632664,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': None,
#   'total_volume': 240450041,
#   'high_24h': 1.01,
#   'low_24h': 0.99126,
#   'price_change_24h': 8.561e-05,
#   'price_change_percentage_24h': 0.00856,
#   'market_cap_change_24h': 85119165,
#   'market_cap_change_percentage_24h': 1.00347,
#   'circulating_supply': 8559951471.13293,
#   'total_supply': 8559191610.95819,
#   'max_supply': None,
#   'ath': 1.09,
#   'ath_change_percentage': -8.33492,
#   'ath_date': '2021-01-11T22:30:57.984Z',
#   'atl': 0.857992,
#   'atl_change_percentage': 16.65579,
#   'atl_date': '2021-05-19T13:14:26.898Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:10.616Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uniswap-uni.png?1600306604',
#   'current_price': 16.16,
#   'market_cap': 7326337416,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 16173811214,
#   'total_volume': 220850040,
#   'high_24h': 17.91,
#   'low_24h': 16.16,
#   'price_change_24h': -1.752309363088,
#   'price_change_percentage_24h': -9.78311,
#   'market_cap_change_24h': -793705643.3004074,
#   'market_cap_change_percentage_24h': -9.77465,
#   'circulating_supply': 452975326.5555916,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -64.00233,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 1469.58953,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:39.749Z'},
#  {'id': 'axie-infinity',
#   'symbol': 'axs',
#   'name': 'Axie Infinity',
#   'image': 'https://assets.coingecko.com/coins/images/13029/large/axie_infinity_logo.png?1604471082',
#   'current_price': 104.53,
#   'market_cap': 7115213836,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 28305998777,
#   'total_volume': 353068241,
#   'high_24h': 115.06,
#   'low_24h': 103.29,
#   'price_change_24h': -8.494278533266,
#   'price_change_percentage_24h': -7.51522,
#   'market_cap_change_24h': -334079443.60233593,
#   'market_cap_change_percentage_24h': -4.48471,
#   'circulating_supply': 67869279.26165423,
#   'total_supply': 270000000.0,
#   'max_supply': 270000000.0,
#   'ath': 164.9,
#   'ath_change_percentage': -36.58853,
#   'ath_date': '2021-11-06T19:29:29.482Z',
#   'atl': 0.123718,
#   'atl_change_percentage': 84417.96301,
#   'atl_date': '2020-11-06T08:05:43.662Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:48.993Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1552356157',
#   'current_price': 0.277746,
#   'market_cap': 6849155444,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 13909425787,
#   'total_volume': 555798242,
#   'high_24h': 0.298815,
#   'low_24h': 0.2743,
#   'price_change_24h': -0.017367047505,
#   'price_change_percentage_24h': -5.88488,
#   'market_cap_change_24h': -427841831.0859518,
#   'market_cap_change_percentage_24h': -5.87937,
#   'circulating_supply': 24621441815.1227,
#   'total_supply': 50001802484.562,
#   'max_supply': 50001802484.562,
#   'ath': 0.875563,
#   'ath_change_percentage': -68.22862,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 58325.71322,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:40.330Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/okb_token.png?1548386209',
#   'current_price': 25.57,
#   'market_cap': 6719339143,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': None,
#   'total_volume': 626755906,
#   'high_24h': 27.18,
#   'low_24h': 24.97,
#   'price_change_24h': -1.302411976672,
#   'price_change_percentage_24h': -4.84681,
#   'market_cap_change_24h': -338126259.6970215,
#   'market_cap_change_percentage_24h': -4.79104,
#   'circulating_supply': 262680011.32,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 44.01,
#   'ath_change_percentage': -41.88044,
#   'ath_date': '2021-05-03T01:03:16.108Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 4304.98418,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:56.229Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1555657960',
#   'current_price': 22.96,
#   'market_cap': 6518917219,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': None,
#   'total_volume': 381278466,
#   'high_24h': 24.94,
#   'low_24h': 22.55,
#   'price_change_24h': -1.535522669171,
#   'price_change_percentage_24h': -6.26916,
#   'market_cap_change_24h': -432971919.1566162,
#   'market_cap_change_percentage_24h': -6.22812,
#   'circulating_supply': 283748700.001938,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 44.42,
#   'ath_change_percentage': -48.27884,
#   'ath_date': '2021-09-20T00:05:25.062Z',
#   'atl': 1.16,
#   'atl_change_percentage': 1880.45259,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 228.5775904773953,
#    'currency': 'usd',
#    'percentage': 22857.75904773953},
#   'last_updated': '2021-12-10T03:24:12.027Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1608607546',
#   'current_price': 4119.8,
#   'market_cap': 6422573323,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 6422573323,
#   'total_volume': 5588204,
#   'high_24h': 4360.9,
#   'low_24h': 4048.3,
#   'price_change_24h': -239.64741821497,
#   'price_change_percentage_24h': -5.49719,
#   'market_cap_change_24h': -356670598.64146805,
#   'market_cap_change_percentage_24h': -5.26122,
#   'circulating_supply': 1557242.88748152,
#   'total_supply': 1557242.88748152,
#   'max_supply': 1557242.88748152,
#   'ath': 4829.57,
#   'ath_change_percentage': -14.60266,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 754.08101,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:45.145Z'},
#  {'id': 'compound-ether',
#   'symbol': 'ceth',
#   'name': 'cETH',
#   'image': 'https://assets.coingecko.com/coins/images/10643/large/ceth2.JPG?1581389598',
#   'current_price': 83.32,
#   'market_cap': 6325330575,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': None,
#   'total_volume': 271011920,
#   'high_24h': 88.06,
#   'low_24h': 80.67,
#   'price_change_24h': -4.719851395985,
#   'price_change_percentage_24h': -5.36113,
#   'market_cap_change_24h': -650841577.396307,
#   'market_cap_change_percentage_24h': -9.32949,
#   'circulating_supply': 75946337.1547876,
#   'total_supply': 75946337.1547876,
#   'max_supply': None,
#   'ath': 97.75,
#   'ath_change_percentage': -14.79656,
#   'ath_date': '2021-11-21T12:39:57.508Z',
#   'atl': 1.89,
#   'atl_change_percentage': 4315.38275,
#   'atl_date': '2020-03-13T02:22:33.711Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:28.793Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VeChain-Logo-768x725.png?1547035194',
#   'current_price': 0.086777,
#   'market_cap': 5798331136,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': None,
#   'total_volume': 358848317,
#   'high_24h': 0.093747,
#   'low_24h': 0.086525,
#   'price_change_24h': -0.006210400147,
#   'price_change_percentage_24h': -6.67875,
#   'market_cap_change_24h': -408533107.45430183,
#   'market_cap_change_percentage_24h': -6.58196,
#   'circulating_supply': 66760741299.0,
#   'total_supply': 86712634466.0,
#   'max_supply': None,
#   'ath': 0.280991,
#   'ath_change_percentage': -69.09069,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 4430.32691,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 6.308435664804084,
#    'currency': 'eth',
#    'percentage': 630.8435664804084},
#   'last_updated': '2021-12-10T03:24:56.103Z'},
#  {'id': 'ftx-token',
#   'symbol': 'ftt',
#   'name': 'FTX Token',
#   'image': 'https://assets.coingecko.com/coins/images/9026/large/F.png?1609051564',
#   'current_price': 40.06,
#   'market_cap': 5585214636,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 13438812061,
#   'total_volume': 123796040,
#   'high_24h': 43.65,
#   'low_24h': 39.81,
#   'price_change_24h': -3.552014358194,
#   'price_change_percentage_24h': -8.14463,
#   'market_cap_change_24h': -493918589.64008236,
#   'market_cap_change_percentage_24h': -8.12482,
#   'circulating_supply': 139295691.31874424,
#   'total_supply': 335165027.385972,
#   'max_supply': 335165027.385972,
#   'ath': 84.18,
#   'ath_change_percentage': -52.36936,
#   'ath_date': '2021-09-09T16:59:43.151Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3387.51944,
#   'atl_date': '2019-09-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:54.001Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'Near',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near_icon.png?1601359077',
#   'current_price': 9.67,
#   'market_cap': 5530174321,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 9641781258,
#   'total_volume': 552157231,
#   'high_24h': 9.87,
#   'low_24h': 8.94,
#   'price_change_24h': 0.200341,
#   'price_change_percentage_24h': 2.11671,
#   'market_cap_change_24h': 96818036,
#   'market_cap_change_percentage_24h': 1.78192,
#   'circulating_supply': 573563553.604799,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 13.2,
#   'ath_change_percentage': -26.94314,
#   'ath_date': '2021-10-26T13:09:48.238Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 1730.38504,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:57.589Z'},
#  {'id': 'elrond-erd-2',
#   'symbol': 'egld',
#   'name': 'Elrond',
#   'image': 'https://assets.coingecko.com/coins/images/12335/large/elrond3_360.png?1626341589',
#   'current_price': 269.16,
#   'market_cap': 5438145286,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': None,
#   'total_volume': 307898386,
#   'high_24h': 309.75,
#   'low_24h': 267.73,
#   'price_change_24h': -22.292078991327,
#   'price_change_percentage_24h': -7.64852,
#   'market_cap_change_24h': -459394250.07308865,
#   'market_cap_change_percentage_24h': -7.78959,
#   'circulating_supply': 20196173.0,
#   'total_supply': 20397843.0,
#   'max_supply': None,
#   'ath': 545.64,
#   'ath_change_percentage': -50.65125,
#   'ath_date': '2021-11-23T10:33:26.737Z',
#   'atl': 6.51,
#   'atl_change_percentage': 4038.31651,
#   'atl_date': '2020-10-07T01:44:53.554Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:40.847Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1620703073',
#   'current_price': 28.78,
#   'market_cap': 5293436692,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 13517008946,
#   'total_volume': 177339976,
#   'high_24h': 31.11,
#   'low_24h': 28.25,
#   'price_change_24h': -1.945802178875,
#   'price_change_percentage_24h': -6.33282,
#   'market_cap_change_24h': -352423153.5049772,
#   'market_cap_change_percentage_24h': -6.24215,
#   'circulating_supply': 183750197.9,
#   'total_supply': 469213710.0,
#   'max_supply': 469213710.0,
#   'ath': 700.65,
#   'ath_change_percentage': -95.8884,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 24.29,
#   'atl_change_percentage': 18.59565,
#   'atl_date': '2021-12-04T05:33:43.785Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:15.508Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1602753933',
#   'current_price': 38.05,
#   'market_cap': 5154084590,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 75049364188,
#   'total_volume': 519363311,
#   'high_24h': 40.59,
#   'low_24h': 37.3,
#   'price_change_24h': -2.251211889234,
#   'price_change_percentage_24h': -5.58602,
#   'market_cap_change_24h': -276380026.09739494,
#   'market_cap_change_percentage_24h': -5.08944,
#   'circulating_supply': 135364777.0,
#   'total_supply': 1971065913.0,
#   'max_supply': 1971065913.0,
#   'ath': 236.84,
#   'ath_change_percentage': -83.92331,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 20.06,
#   'atl_change_percentage': 89.8148,
#   'atl_date': '2020-12-29T22:32:28.483Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:53.899Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1547034169',
#   'current_price': 37.9,
#   'market_cap': 5001166645,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 8011294434,
#   'total_volume': 636944149,
#   'high_24h': 40.41,
#   'low_24h': 37.45,
#   'price_change_24h': -2.060803256125,
#   'price_change_percentage_24h': -5.15642,
#   'market_cap_change_24h': -257731181.45820522,
#   'market_cap_change_percentage_24h': -4.90086,
#   'circulating_supply': 131532528.344886,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -77.2438,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 6082.1026,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 83.2333244016989,
#    'currency': 'usd',
#    'percentage': 8323.332440169888},
#   'last_updated': '2021-12-10T03:24:20.659Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1597397942',
#   'current_price': 5.25,
#   'market_cap': 4796726083,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 15755129930,
#   'total_volume': 1226942744,
#   'high_24h': 5.67,
#   'low_24h': 5.11,
#   'price_change_24h': -0.016764449804,
#   'price_change_percentage_24h': -0.31821,
#   'market_cap_change_24h': -22812698.153388023,
#   'market_cap_change_percentage_24h': -0.47334,
#   'circulating_supply': 913364619.2233225,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -37.43263,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 18030.02918,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:39.383Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1637045634',
#   'current_price': 0.258016,
#   'market_cap': 4720417726,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': None,
#   'total_volume': 79325354,
#   'high_24h': 0.288351,
#   'low_24h': 0.252704,
#   'price_change_24h': -0.016934204087,
#   'price_change_percentage_24h': -6.15901,
#   'market_cap_change_24h': -306704725.21140194,
#   'market_cap_change_percentage_24h': -6.101,
#   'circulating_supply': 18287622674.0,
#   'total_supply': 50000000000.0,
#   'max_supply': None,
#   'ath': 0.569229,
#   'ath_change_percentage': -54.65429,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 2517.5643,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:18.659Z'},
#  {'id': 'decentraland',
#   'symbol': 'mana',
#   'name': 'Decentraland',
#   'image': 'https://assets.coingecko.com/coins/images/878/large/decentraland-mana.png?1550108745',
#   'current_price': 3.49,
#   'market_cap': 4644568362,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 7676819520,
#   'total_volume': 849012910,
#   'high_24h': 3.86,
#   'low_24h': 3.43,
#   'price_change_24h': -0.244260890513,
#   'price_change_percentage_24h': -6.54794,
#   'market_cap_change_24h': -321781370.49458504,
#   'market_cap_change_percentage_24h': -6.47923,
#   'circulating_supply': 1327372145.9864838,
#   'total_supply': 2193959827.32015,
#   'max_supply': 2193959827.32015,
#   'ath': 5.85,
#   'ath_change_percentage': -40.19522,
#   'ath_date': '2021-11-25T10:04:18.534Z',
#   'atl': 0.00923681,
#   'atl_change_percentage': 37781.81211,
#   'atl_date': '2017-10-31T00:00:00.000Z',
#   'roi': {'times': 173.3041758336632,
#    'currency': 'usd',
#    'percentage': 17330.41758336632},
#   'last_updated': '2021-12-10T03:26:03.227Z'},
#  {'id': 'cdai',
#   'symbol': 'cdai',
#   'name': 'cDAI',
#   'image': 'https://assets.coingecko.com/coins/images/9281/large/cDAI.png?1576467585',
#   'current_price': 0.02170595,
#   'market_cap': 4626108013,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': None,
#   'total_volume': 3084092,
#   'high_24h': 0.02210667,
#   'low_24h': 0.02160233,
#   'price_change_24h': -5.1498504e-05,
#   'price_change_percentage_24h': -0.23669,
#   'market_cap_change_24h': -8202592.118861198,
#   'market_cap_change_percentage_24h': -0.177,
#   'circulating_supply': 213041294668.74,
#   'total_supply': 213041294668.74,
#   'max_supply': None,
#   'ath': 0.03159087,
#   'ath_change_percentage': -31.26302,
#   'ath_date': '2020-10-12T21:29:00.007Z',
#   'atl': 0.00728854,
#   'atl_change_percentage': 197.92792,
#   'atl_date': '2020-03-18T04:29:40.819Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:25.375Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1548387191',
#   'current_price': 4.46,
#   'market_cap': 4457710873,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': None,
#   'total_volume': 183409698,
#   'high_24h': 4.84,
#   'low_24h': 4.38,
#   'price_change_24h': -0.378605321828,
#   'price_change_percentage_24h': -7.83273,
#   'market_cap_change_24h': -385302550.4977541,
#   'market_cap_change_percentage_24h': -7.95584,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 15.72,
#   'ath_change_percentage': -71.64255,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 10933.9939,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 28.70018848560632,
#    'currency': 'usd',
#    'percentage': 2870.018848560632},
#   'last_updated': '2021-12-10T03:25:57.639Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1547034862',
#   'current_price': 4.78,
#   'market_cap': 4165302105,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': None,
#   'total_volume': 431287106,
#   'high_24h': 5.46,
#   'low_24h': 4.78,
#   'price_change_24h': -0.684617593849,
#   'price_change_percentage_24h': -12.53038,
#   'market_cap_change_24h': -594625687.4833055,
#   'market_cap_change_percentage_24h': -12.49233,
#   'circulating_supply': 869292721.64167,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 9.12,
#   'ath_change_percentage': -47.43786,
#   'ath_date': '2021-10-04T00:41:18.025Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 1267.16895,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 9.168181354289194,
#    'currency': 'usd',
#    'percentage': 916.8181354289194},
#   'last_updated': '2021-12-10T03:25:04.332Z'},
#  {'id': 'magic-internet-money',
#   'symbol': 'mim',
#   'name': 'Magic Internet Money',
#   'image': 'https://assets.coingecko.com/coins/images/16786/large/mimlogopng.png?1624979612',
#   'current_price': 0.999572,
#   'market_cap': 3870205913,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': None,
#   'total_volume': 443087069,
#   'high_24h': 1.01,
#   'low_24h': 0.989917,
#   'price_change_24h': -0.003070220295,
#   'price_change_percentage_24h': -0.30621,
#   'market_cap_change_24h': 146651880,
#   'market_cap_change_percentage_24h': 3.93849,
#   'circulating_supply': 3869748141.24997,
#   'total_supply': 3869748141.24997,
#   'max_supply': None,
#   'ath': 1.04,
#   'ath_change_percentage': -3.93217,
#   'ath_date': '2021-10-06T13:25:17.751Z',
#   'atl': 0.919196,
#   'atl_change_percentage': 8.80365,
#   'atl_date': '2021-12-04T05:29:56.806Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:18.446Z'},
#  {'id': 'compound-usd-coin',
#   'symbol': 'cusdc',
#   'name': 'cUSDC',
#   'image': 'https://assets.coingecko.com/coins/images/9442/large/Compound_USDC.png?1567581577',
#   'current_price': 0.02234507,
#   'market_cap': 3859621207,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': None,
#   'total_volume': 48055337,
#   'high_24h': 0.02273567,
#   'low_24h': 0.02225566,
#   'price_change_24h': -6.0870677e-05,
#   'price_change_percentage_24h': -0.27167,
#   'market_cap_change_24h': 44768508,
#   'market_cap_change_percentage_24h': 1.17353,
#   'circulating_supply': 172666514434.154,
#   'total_supply': 172666514434.154,
#   'max_supply': None,
#   'ath': 0.058843,
#   'ath_change_percentage': -62.01268,
#   'ath_date': '2020-10-21T11:24:27.820Z',
#   'atl': 0.00620705,
#   'atl_change_percentage': 260.12313,
#   'atl_date': '2021-03-04T08:11:37.438Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:22:27.354Z'},
#  {'id': 'gala',
#   'symbol': 'gala',
#   'name': 'Gala',
#   'image': 'https://assets.coingecko.com/coins/images/12493/large/GALA-COINGECKO.png?1600233435',
#   'current_price': 0.505945,
#   'market_cap': 3821448551,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 25332782818,
#   'total_volume': 1382032508,
#   'high_24h': 0.552868,
#   'low_24h': 0.487216,
#   'price_change_24h': 0.01481318,
#   'price_change_percentage_24h': 3.01613,
#   'market_cap_change_24h': 118529748,
#   'market_cap_change_percentage_24h': 3.20098,
#   'circulating_supply': 7542496572.319239,
#   'total_supply': 36312701872.4241,
#   'max_supply': 50000000000.0,
#   'ath': 0.824837,
#   'ath_change_percentage': -38.57502,
#   'ath_date': '2021-11-26T01:03:48.731Z',
#   'atl': 0.00013475,
#   'atl_change_percentage': 375898.64926,
#   'atl_date': '2020-12-28T08:46:48.367Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:19.565Z'},
#  {'id': 'fantom',
#   'symbol': 'ftm',
#   'name': 'Fantom',
#   'image': 'https://assets.coingecko.com/coins/images/4001/large/Fantom.png?1558015016',
#   'current_price': 1.43,
#   'market_cap': 3653060533,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 4564254265,
#   'total_volume': 302755844,
#   'high_24h': 1.59,
#   'low_24h': 1.41,
#   'price_change_24h': -0.130407306646,
#   'price_change_percentage_24h': -8.35456,
#   'market_cap_change_24h': -313434013.53206825,
#   'market_cap_change_percentage_24h': -7.90204,
#   'circulating_supply': 2541152731.01,
#   'total_supply': 3175000000.0,
#   'max_supply': 3175000000.0,
#   'ath': 3.46,
#   'ath_change_percentage': -58.43488,
#   'ath_date': '2021-10-28T05:19:39.845Z',
#   'atl': 0.00190227,
#   'atl_change_percentage': 75470.7965,
#   'atl_date': '2020-03-13T02:25:38.280Z',
#   'roi': {'times': 46.6835054928505,
#    'currency': 'usd',
#    'percentage': 4668.35054928505},
#   'last_updated': '2021-12-10T03:24:40.823Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1558326215',
#   'current_price': 3.71,
#   'market_cap': 3482519886,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': None,
#   'total_volume': 493899,
#   'high_24h': 3.74,
#   'low_24h': 3.6,
#   'price_change_24h': 0.071267,
#   'price_change_percentage_24h': 1.96109,
#   'market_cap_change_24h': 68700705,
#   'market_cap_change_percentage_24h': 2.01243,
#   'circulating_supply': 939833336.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 3.95,
#   'ath_change_percentage': -6.07488,
#   'ath_date': '2021-05-14T13:54:31.192Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 363.26472,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:45.401Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1608145566',
#   'current_price': 0.693983,
#   'market_cap': 3442334030,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 6944606639,
#   'total_volume': 156930086,
#   'high_24h': 0.760947,
#   'low_24h': 0.682847,
#   'price_change_24h': -0.054450325896,
#   'price_change_percentage_24h': -7.27524,
#   'market_cap_change_24h': -276268088.2041068,
#   'market_cap_change_percentage_24h': -7.42935,
#   'circulating_supply': 4956845231.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.84,
#   'ath_change_percentage': -75.56001,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.103254,
#   'atl_change_percentage': 572.57582,
#   'atl_date': '2020-12-17T21:28:41.332Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:34.012Z'},
#  {'id': 'klay-token',
#   'symbol': 'klay',
#   'name': 'Klaytn',
#   'image': 'https://assets.coingecko.com/coins/images/9672/large/CjbT82vP_400x400.jpg?1570548320',
#   'current_price': 1.35,
#   'market_cap': 3434752164,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': None,
#   'total_volume': 21711433,
#   'high_24h': 1.47,
#   'low_24h': 1.33,
#   'price_change_24h': -0.062578987643,
#   'price_change_percentage_24h': -4.4447,
#   'market_cap_change_24h': -157256829.63347864,
#   'market_cap_change_percentage_24h': -4.37796,
#   'circulating_supply': 2552126691.8,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 4.34,
#   'ath_change_percentage': -68.98209,
#   'ath_date': '2021-03-30T03:44:28.828Z',
#   'atl': 0.06044,
#   'atl_change_percentage': 2126.75283,
#   'atl_date': '2020-04-29T08:19:34.574Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:51.345Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1547033729',
#   'current_price': 189.61,
#   'market_cap': 3422196726,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': None,
#   'total_volume': 143726708,
#   'high_24h': 205.34,
#   'low_24h': 188.66,
#   'price_change_24h': -14.815139539319,
#   'price_change_percentage_24h': -7.24705,
#   'market_cap_change_24h': -268156729.26037788,
#   'market_cap_change_percentage_24h': -7.26642,
#   'circulating_supply': 18043154.84793,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -65.02703,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 87637.18724,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:58.542Z'},
#  {'id': 'iota',
#   'symbol': 'miota',
#   'name': 'IOTA',
#   'image': 'https://assets.coingecko.com/coins/images/692/large/IOTA_Swirl.png?1604238557',
#   'current_price': 1.15,
#   'market_cap': 3189720419,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': None,
#   'total_volume': 70178601,
#   'high_24h': 1.23,
#   'low_24h': 1.14,
#   'price_change_24h': -0.027199717147,
#   'price_change_percentage_24h': -2.31671,
#   'market_cap_change_24h': -75448072.04949951,
#   'market_cap_change_percentage_24h': -2.31069,
#   'circulating_supply': 2779530283.277761,
#   'total_supply': 2779530283.0,
#   'max_supply': None,
#   'ath': 5.25,
#   'ath_change_percentage': -78.13634,
#   'ath_date': '2017-12-19T00:00:00.000Z',
#   'atl': 0.081637,
#   'atl_change_percentage': 1305.69852,
#   'atl_date': '2020-03-13T02:22:41.168Z',
#   'roi': {'times': 16.66936135782297,
#    'currency': 'btc',
#    'percentage': 1666.936135782297},
#   'last_updated': '2021-12-10T03:25:49.233Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1547034481',
#   'current_price': 3.26,
#   'market_cap': 3183615342,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': None,
#   'total_volume': 1016720425,
#   'high_24h': 3.53,
#   'low_24h': 3.23,
#   'price_change_24h': -0.275184700821,
# ...
#   'total_volume': 175442391,
#   'high_24h': 0.00989055,
#   'low_24h': 0.00902869,
#   'price_change_24h': -0.000629122612,
#   'price_change_percentage_24h': -6.42942,
#   'market_cap_change_24h': -111630044.70863128,
#   'market_cap_change_percentage_24h': -6.41898,
#   'circulating_supply': 177619433541.141,
#   'total_supply': 177619433541.141,
#   'max_supply': None,
#   'ath': 0.03126682,
#   'ath_change_percentage': -70.69589,
#   'ath_date': '2021-04-05T16:04:52.608Z',
#   'atl': 0.0002202,
#   'atl_change_percentage': 4060.99417,
#   'atl_date': '2020-03-13T02:23:01.612Z',
#   'roi': {'times': 8.716631017559031,
#    'currency': 'eth',
#    'percentage': 871.6631017559031},
#   'last_updated': '2021-12-10T03:23:15.684Z'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'image': 'https://assets.coingecko.com/coins/images/8834/large/Chiliz.png?1561970540',
#   'current_price': 0.300215,
#   'market_cap': 1605967939,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 2671238409,
#   'total_volume': 178446435,
#   'high_24h': 0.327223,
#   'low_24h': 0.30042,
#   'price_change_24h': -0.021200317498,
#   'price_change_percentage_24h': -6.59593,
#   'market_cap_change_24h': -112094400.3409915,
#   'market_cap_change_percentage_24h': -6.52447,
#   'circulating_supply': 5344064580.0,
#   'total_supply': 8888888888.0,
#   'max_supply': 8888888888.0,
#   'ath': 0.878633,
#   'ath_change_percentage': -65.79753,
#   'ath_date': '2021-03-13T08:04:21.200Z',
#   'atl': 0.00410887,
#   'atl_change_percentage': 7213.78672,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 12.646129898053218,
#    'currency': 'usd',
#    'percentage': 1264.6129898053218},
#   'last_updated': '2021-12-10T03:25:00.195Z'},
#  {'id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'name': 'KuCoin Token',
#   'image': 'https://assets.coingecko.com/coins/images/1047/large/sa9z79.png?1610678720',
#   'current_price': 20.69,
#   'market_cap': 1595147465,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': None,
#   'total_volume': 27736037,
#   'high_24h': 22.16,
#   'low_24h': 20.02,
#   'price_change_24h': -1.215835169578,
#   'price_change_percentage_24h': -5.55038,
#   'market_cap_change_24h': -100581502.3497045,
#   'market_cap_change_percentage_24h': -5.93146,
#   'circulating_supply': 77073331.0,
#   'total_supply': 167073331.0,
#   'max_supply': None,
#   'ath': 28.83,
#   'ath_change_percentage': -28.21169,
#   'ath_date': '2021-12-01T15:09:35.541Z',
#   'atl': 0.342863,
#   'atl_change_percentage': 5936.37188,
#   'atl_date': '2019-02-07T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:21.383Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi Token',
#   'image': 'https://assets.coingecko.com/coins/images/2822/large/huobi-token-logo.png?1547036992',
#   'current_price': 9.99,
#   'market_cap': 1593567715,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 5001512951,
#   'total_volume': 156104460,
#   'high_24h': 10.21,
#   'low_24h': 9.68,
#   'price_change_24h': 0.167458,
#   'price_change_percentage_24h': 1.70411,
#   'market_cap_change_24h': 28124394,
#   'market_cap_change_percentage_24h': 1.79658,
#   'circulating_supply': 159308566.25441208,
#   'total_supply': 500000000.0,
#   'max_supply': 500000000.0,
#   'ath': 39.66,
#   'ath_change_percentage': -74.77854,
#   'ath_date': '2021-05-12T14:42:21.586Z',
#   'atl': 0.90862,
#   'atl_change_percentage': 1000.90331,
#   'atl_date': '2019-01-30T00:00:00.000Z',
#   'roi': {'times': 9.095150606705786,
#    'currency': 'usd',
#    'percentage': 909.5150606705786},
#   'last_updated': '2021-12-10T03:24:27.360Z'},
#  {'id': 'link',
#   'symbol': 'ln',
#   'name': 'LINK',
#   'image': 'https://assets.coingecko.com/coins/images/6450/large/linklogo.png?1547042644',
#   'current_price': 244.66,
#   'market_cap': 1462025805,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': None,
#   'total_volume': 5284098,
#   'high_24h': 264.67,
#   'low_24h': 238.29,
#   'price_change_24h': -18.083743491161,
#   'price_change_percentage_24h': -6.88278,
#   'market_cap_change_24h': -118918908.41026044,
#   'market_cap_change_percentage_24h': -7.52202,
#   'circulating_supply': 5976007.63607,
#   'total_supply': 6045959.0,
#   'max_supply': None,
#   'ath': 345.88,
#   'ath_change_percentage': -29.2685,
#   'ath_date': '2021-04-01T22:19:00.034Z',
#   'atl': 1.05,
#   'atl_change_percentage': 23089.53564,
#   'atl_date': '2018-12-26T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:21:58.048Z'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'image': 'https://assets.coingecko.com/coins/images/19/large/dash-logo.png?1548385930',
#   'current_price': 139.28,
#   'market_cap': 1460310792,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': None,
#   'total_volume': 307470904,
#   'high_24h': 148.15,
#   'low_24h': 136.46,
#   'price_change_24h': -4.295050105733,
#   'price_change_percentage_24h': -2.99142,
#   'market_cap_change_24h': -42668862.40016794,
#   'market_cap_change_percentage_24h': -2.83895,
#   'circulating_supply': 10471811.242325,
#   'total_supply': 18920000.0,
#   'max_supply': None,
#   'ath': 1493.59,
#   'ath_change_percentage': -90.66333,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 0.213899,
#   'atl_change_percentage': 65095.06689,
#   'atl_date': '2014-02-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:44.889Z'},
#  {'id': 'celo',
#   'symbol': 'celo',
#   'name': 'Celo',
#   'image': 'https://assets.coingecko.com/coins/images/11090/large/icon-celo-CELO-color-500.png?1592293590',
#   'current_price': 3.98,
#   'market_cap': 1459195686,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 3973795816,
#   'total_volume': 57568236,
#   'high_24h': 4.32,
#   'low_24h': 3.75,
#   'price_change_24h': -0.31148764097,
#   'price_change_percentage_24h': -7.26223,
#   'market_cap_change_24h': -100829456.51711822,
#   'market_cap_change_percentage_24h': -6.46332,
#   'circulating_supply': 367204495.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 9.82,
#   'ath_change_percentage': -59.53901,
#   'ath_date': '2021-08-30T14:25:09.929Z',
#   'atl': 0.800156,
#   'atl_change_percentage': 396.62784,
#   'atl_date': '2020-05-22T04:15:27.736Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:43.030Z'},
#  {'id': 'curve-dao-token',
#   'symbol': 'crv',
#   'name': 'Curve DAO Token',
#   'image': 'https://assets.coingecko.com/coins/images/12124/large/Curve.png?1597369484',
#   'current_price': 3.69,
#   'market_cap': 1449984533,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 12219017421,
#   'total_volume': 257138661,
#   'high_24h': 4.1,
#   'low_24h': 3.62,
#   'price_change_24h': -0.317057675923,
#   'price_change_percentage_24h': -7.91363,
#   'market_cap_change_24h': -122198687.03860664,
#   'market_cap_change_percentage_24h': -7.77255,
#   'circulating_supply': 391958099.3931446,
#   'total_supply': 1647047775.69211,
#   'max_supply': 3303030299.0,
#   'ath': 54.01,
#   'ath_change_percentage': -93.15065,
#   'ath_date': '2020-08-14T04:53:44.010Z',
#   'atl': 0.331577,
#   'atl_change_percentage': 1015.59866,
#   'atl_date': '2020-11-05T13:09:50.181Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:24.859Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Frax',
#   'image': 'https://assets.coingecko.com/coins/images/13422/large/frax_logo.png?1608476506',
#   'current_price': 1.0,
#   'market_cap': 1427850305,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1427850305,
#   'total_volume': 35476610,
#   'high_24h': 1.02,
#   'low_24h': 0.988327,
#   'price_change_24h': 0.00132237,
#   'price_change_percentage_24h': 0.13225,
#   'market_cap_change_24h': 53979072,
#   'market_cap_change_percentage_24h': 3.92898,
#   'circulating_supply': 1425574681.90788,
#   'total_supply': 1425574681.90788,
#   'max_supply': 1425574681.90788,
#   'ath': 1.14,
#   'ath_change_percentage': -12.17545,
#   'ath_date': '2021-02-07T12:55:35.766Z',
#   'atl': 0.891635,
#   'atl_change_percentage': 12.3325,
#   'atl_date': '2021-12-04T05:33:57.315Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:23:44.279Z'},
#  {'id': 'ecomi',
#   'symbol': 'omi',
#   'name': 'ECOMI',
#   'image': 'https://assets.coingecko.com/coins/images/4428/large/ECOMI.png?1557928886',
#   'current_price': 0.00569315,
#   'market_cap': 1353204427,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': None,
#   'total_volume': 15150183,
#   'high_24h': 0.00615157,
#   'low_24h': 0.00544761,
#   'price_change_24h': -0.00013130789,
#   'price_change_percentage_24h': -2.25442,
#   'market_cap_change_24h': -31210549.950327873,
#   'market_cap_change_percentage_24h': -2.25442,
#   'circulating_supply': 237689829874.317,
#   'total_supply': 750000000000.0,
#   'max_supply': None,
#   'ath': 0.01343572,
#   'ath_change_percentage': -57.62674,
#   'ath_date': '2021-03-19T17:20:53.999Z',
#   'atl': 3.37e-06,
#   'atl_change_percentage': 168788.52955,
#   'atl_date': '2019-11-04T10:52:42.729Z',
#   'roi': {'times': 10.74776220627885,
#    'currency': 'btc',
#    'percentage': 1074.776220627885},
#   'last_updated': '2021-12-10T03:15:45.522Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'image': 'https://assets.coingecko.com/coins/images/3449/large/tusd.png?1618395665',
#   'current_price': 0.997897,
#   'market_cap': 1299052848,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': None,
#   'total_volume': 140792287,
#   'high_24h': 1.01,
#   'low_24h': 0.989528,
#   'price_change_24h': -0.000937738864,
#   'price_change_percentage_24h': -0.09388,
#   'market_cap_change_24h': 4422345,
#   'market_cap_change_percentage_24h': 0.34159,
#   'circulating_supply': 1301077078.61385,
#   'total_supply': 1301077078.61385,
#   'max_supply': None,
#   'ath': 1.62,
#   'ath_change_percentage': -38.31101,
#   'ath_date': '2018-08-26T20:41:09.375Z',
#   'atl': 0.88355,
#   'atl_change_percentage': 13.00372,
#   'atl_date': '2020-03-12T10:47:51.380Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:36.010Z'},
#  {'id': 'msol',
#   'symbol': 'msol',
#   'name': 'Marinade staked SOL',
#   'image': 'https://assets.coingecko.com/coins/images/17752/large/PJ7Scn3.png?1629175951',
#   'current_price': 184.82,
#   'market_cap': 1264741430,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 1264741430,
#   'total_volume': 56350327,
#   'high_24h': 195.8,
#   'low_24h': 183.61,
#   'price_change_24h': -9.854158472767,
#   'price_change_percentage_24h': -5.06192,
#   'market_cap_change_24h': -58975130.41653967,
#   'market_cap_change_percentage_24h': -4.45527,
#   'circulating_supply': 6836606.35245384,
#   'total_supply': 6836606.35245384,
#   'max_supply': 6836606.35245384,
#   'ath': 3541.84,
#   'ath_change_percentage': -94.77685,
#   'ath_date': '2021-08-23T22:16:35.076Z',
#   'atl': 42.4,
#   'atl_change_percentage': 336.31887,
#   'atl_date': '2021-08-30T10:27:09.425Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:03.166Z'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'image': 'https://assets.coingecko.com/coins/images/3695/large/nexo.png?1548086057',
#   'current_price': 2.23,
#   'market_cap': 1256592839,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 2243915744,
#   'total_volume': 7276489,
#   'high_24h': 2.36,
#   'low_24h': 2.17,
#   'price_change_24h': -0.110498109833,
#   'price_change_percentage_24h': -4.71334,
#   'market_cap_change_24h': -49929419.04758763,
#   'market_cap_change_percentage_24h': -3.82155,
#   'circulating_supply': 560000010.0064,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.07,
#   'ath_change_percentage': -44.83943,
#   'ath_date': '2021-05-12T14:37:47.535Z',
#   'atl': 0.04515276,
#   'atl_change_percentage': 4869.60908,
#   'atl_date': '2018-09-13T00:00:00.000Z',
#   'roi': {'times': 21.3387229965217,
#    'currency': 'usd',
#    'percentage': 2133.87229965217},
#   'last_updated': '2021-12-10T03:25:39.951Z'},
#  {'id': 'iotex',
#   'symbol': 'iotx',
#   'name': 'IoTeX',
#   'image': 'https://assets.coingecko.com/coins/images/3334/large/iotex-logo.png?1547037941',
#   'current_price': 0.132033,
#   'market_cap': 1249460643,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 1250176486,
#   'total_volume': 230201851,
#   'high_24h': 0.132,
#   'low_24h': 0.112584,
#   'price_change_24h': 0.01832139,
#   'price_change_percentage_24h': 16.11218,
#   'market_cap_change_24h': 167257488,
#   'market_cap_change_percentage_24h': 15.45528,
#   'circulating_supply': 9490829322.48387,
#   'total_supply': 9496266827.32,
#   'max_supply': 9496266827.32,
#   'ath': 0.255593,
#   'ath_change_percentage': -48.49253,
#   'ath_date': '2021-11-13T16:54:18.643Z',
#   'atl': 0.00121576,
#   'atl_change_percentage': 10728.57363,
#   'atl_date': '2020-03-13T02:29:47.597Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:26:04.583Z'},
#  {'id': 'nem',
#   'symbol': 'xem',
#   'name': 'NEM',
#   'image': 'https://assets.coingecko.com/coins/images/242/large/NEM_Logo_256x256.png?1598687029',
#   'current_price': 0.136502,
#   'market_cap': 1229794414,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 32099637,
#   'high_24h': 0.142466,
#   'low_24h': 0.13267,
#   'price_change_24h': -0.005535432496,
#   'price_change_percentage_24h': -3.89718,
#   'market_cap_change_24h': -46535633.77278662,
#   'market_cap_change_percentage_24h': -3.64605,
#   'circulating_supply': 8999999999.0,
#   'total_supply': 8999999999.0,
#   'max_supply': None,
#   'ath': 1.87,
#   'ath_change_percentage': -92.68713,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 8.482e-05,
#   'atl_change_percentage': 161004.85582,
#   'atl_date': '2015-09-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:26:03.988Z'},
#  {'id': 'compound-governance-token',
#   'symbol': 'comp',
#   'name': 'Compound',
#   'image': 'https://assets.coingecko.com/coins/images/10775/large/COMP.png?1592625425',
#   'current_price': 195.76,
#   'market_cap': 1217782792,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 1961752250,
#   'total_volume': 168956807,
#   'high_24h': 214.25,
#   'low_24h': 194.31,
#   'price_change_24h': -17.507188948676,
#   'price_change_percentage_24h': -8.20894,
#   'market_cap_change_24h': -107095828.64924693,
#   'market_cap_change_percentage_24h': -8.08344,
#   'circulating_supply': 6207627.858505316,
#   'total_supply': 10000000.0,
#   'max_supply': 10000000.0,
#   'ath': 910.54,
#   'ath_change_percentage': -78.45513,
#   'ath_date': '2021-05-12T02:29:08.794Z',
#   'atl': 61.32,
#   'atl_change_percentage': 219.91039,
#   'atl_date': '2020-06-18T12:54:32.788Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:24:45.331Z'},
#  {'id': 'mina-protocol',
#   'symbol': 'mina',
#   'name': 'Mina Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/15628/large/JM4_vQ34_400x400.png?1621394004',
#   'current_price': 3.61,
#   'market_cap': 1143152929,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': None,
#   'total_volume': 30899121,
#   'high_24h': 3.89,
#   'low_24h': 3.54,
#   'price_change_24h': -0.27155241763,
#   'price_change_percentage_24h': -7.00476,
#   'market_cap_change_24h': -80901613.5512898,
#   'market_cap_change_percentage_24h': -6.60931,
#   'circulating_supply': 316777889.840039,
#   'total_supply': 876934972.840039,
#   'max_supply': None,
#   'ath': 9.09,
#   'ath_change_percentage': -60.33259,
#   'ath_date': '2021-06-01T01:42:37.064Z',
#   'atl': 0.925536,
#   'atl_change_percentage': 289.60183,
#   'atl_date': '2021-07-21T02:30:02.124Z',
#   'roi': None,
#   'last_updated': '2021-12-10T03:25:44.731Z'},
#  {'id': 'paxos-standard',
#   'symbol': 'usdp',
#   'name': 'Pax Dollar',
#   'image': 'https://assets.coingecko.com/coins/images/6013/large/Pax_Dollar.png?1629877204',
#   'current_price': 0.998362,
#   'market_cap': 1141938210,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': None,
#   'total_volume': 5357720,
#   'high_24h': 1.01,
#   'low_24h': 0.988679,
#   'price_change_24h': -0.00080830374,
#   'price_change_percentage_24h': -0.0809,
#   'market_cap_change_24h': 6741063,
#   'market_cap_change_percentage_24h': 0.59382,
#   'circulating_supply': 1142147714.29,
#   'total_supply': 1142147714.29,
#   'max_supply': None,
#   'ath': 1.13,
#   'ath_change_percentage': -11.33821,
#   'ath_date': '2018-10-15T07:09:12.459Z',
#   'atl': 0.863529,
#   'atl_change_percentage': 15.78263,
#   'atl_date': '2021-05-19T13:14:42.046Z',
#   'roi': {'times': -0.0016379573390451,
#    'currency': 'usd',
#    'percentage': -0.16379573390451},
#   'last_updated': '2021-12-10T03:24:10.083Z'}]

# %% [markdown]
# The downside with this API is we can only get 250 coins per call. To get around this, I'm going to make four API calls and concat them into a single dataframe.

# %%
first_250_coins=cg.get_coins_markets(vs_currency='usd',per_page=250,page=1,price_change_percentage
='24h,7d')
df1=pd.DataFrame(first_250_coins)
second_250_coins=cg.get_coins_markets(vs_currency='usd',per_page=250,page=2,price_change_percentage
='24h,7d')
df2=pd.DataFrame(second_250_coins)
third_250_coins=cg.get_coins_markets(vs_currency='usd',per_page=250,page=3,price_change_percentage
='24h,7d')
df3=pd.DataFrame(third_250_coins)
forth_250_coins=cg.get_coins_markets(vs_currency='usd',per_page=250,page=4,price_change_percentage
='24h,7d')
df4=pd.DataFrame(forth_250_coins)
df=pd.concat([df1,df2,df3,df4],ignore_index=True,)
df
# Out:
#                   id  symbol             name  \
# 0            bitcoin     btc          Bitcoin
# 1           ethereum     eth         Ethereum
# 2        binancecoin     bnb     Binance Coin
# 3             tether    usdt           Tether
# 4             solana     sol           Solana
# ..               ...     ...              ...
# 995           pibble     pib           Pibble
# 996           draken     drk           Draken
# 997     nectar-token     nec           Nectar
# 998     etherrock-72  pebble    Etherrock #72
# 999  mirrored-google  mgoogl  Mirrored Google
#
#                                                  image  current_price  \
# 0    https://assets.coingecko.com/coins/images/1/la...        48471.0
# 1    https://assets.coingecko.com/coins/images/279/...        4155.24
# 2    https://assets.coingecko.com/coins/images/825/...         579.28
# 3    https://assets.coingecko.com/coins/images/325/...       0.999768
# 4    https://assets.coingecko.com/coins/images/4128...         180.92
# ..                                                 ...            ...
# 995  https://assets.coingecko.com/coins/images/2972...     0.00156062
# 996  https://assets.coingecko.com/coins/images/1575...     0.01879855
# 997  https://assets.coingecko.com/coins/images/3559...       0.115536
# 998  https://assets.coingecko.com/coins/images/1796...     0.00025237
# 999  https://assets.coingecko.com/coins/images/1364...         2961.6
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0    916676439150                1          1018707947174.0 28270596038.0
# 1    493586415595                2                      NaN 24070832561.0
# 2     97595424357                3            97595424357.0  2007815364.0
# 3     77180934430                4                      NaN 60269165356.0
# 4     55705620939                5                      NaN  1809924235.0
# ..            ...              ...                      ...           ...
# 995      18337115              996                      NaN       39357.0
# 996      18336932              997               84198721.0           0.0
# 997      18292367              998               71416803.0           0.0
# 998      18170414              999               18170414.0       2963.19
# 999      18162605             1000                      NaN      621085.0
#
#       high_24h  ...        ath  ath_change_percentage  \
# 0      50308.0  ...    69045.0              -29.74138
# 1      4407.44  ...    4878.26              -14.74185
# 2       607.33  ...     686.31              -15.42898
# 3         1.01  ...       1.32              -24.42195
# 4       191.93  ...     259.96              -30.27882
# ..         ...  ...        ...                    ...
# 995 0.00161959  ... 0.02623939              -94.04919
# 996 0.01887865  ... 0.04441833              -57.67838
# 997   0.115536  ...   0.666145              -82.65601
# 998 0.00025439  ... 0.00228217              -88.94179
# 999    2987.37  ...    3112.79               -4.82657
#
#                      ath_date        atl  atl_change_percentage  \
# 0    2021-11-10T14:24:11.849Z      67.81            71439.03206
# 1    2021-11-10T14:24:19.604Z   0.432979           960481.45801
# 2    2021-05-10T07:24:17.097Z  0.0398177          1457584.69949
# 3    2018-07-24T00:00:00.000Z   0.572521               74.66078
# 4    2021-11-06T21:54:35.825Z   0.500801            36091.33735
# ..                        ...        ...                    ...
# 995  2021-04-02T09:08:22.703Z  5.627e-05             2674.73595
# 996  2021-07-20T01:12:27.834Z 0.00701652               167.9186
# 997  2018-05-15T00:11:18.020Z 0.00102922            11125.63507
# 998  2021-10-24T07:48:52.955Z  3.129e-05              706.45931
# 999  2021-11-10T14:30:45.284Z    1654.63               79.04607
#
#                      atl_date  \
# 0    2013-07-06T00:00:00.000Z
# 1    2015-10-20T00:00:00.000Z
# 2    2017-10-19T00:00:00.000Z
# 3    2015-03-02T00:00:00.000Z
# 4    2020-05-11T19:35:23.449Z
# ..                        ...
# 995  2020-05-06T23:55:04.172Z
# 996  2021-06-01T11:25:41.506Z
# 997  2018-12-17T00:00:00.000Z
# 998  2021-08-30T10:43:31.102Z
# 999  2021-01-18T05:38:41.649Z
#
#                                                    roi  \
# 0                                                 None
# 1    {'times': 113.69423777357225, 'currency': 'btc...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995  {'times': -0.9248934563020185, 'currency': 'et...
# 996                                               None
# 997                                               None
# 998                                               None
# 999                                               None
#
#                  last_updated  price_change_percentage_24h_in_currency  \
# 0    2021-12-10T03:25:00.060Z                      -2.7924383263404384
# 1    2021-12-10T03:24:18.385Z                        -5.45337672861116
# 2    2021-12-10T03:25:40.240Z                       -4.047705974219436
# 3    2021-12-10T03:22:31.902Z                     -0.10801497173107566
# 4    2021-12-10T03:24:53.168Z                       -4.902930781530062
# ..                        ...                                      ...
# 995  2021-12-10T03:24:07.951Z                       -3.641464772998457
# 996  2021-12-10T03:18:49.179Z                     -0.31430650535809584
# 997  2021-12-10T03:18:46.561Z                                      0.0
# 998  2021-12-10T03:14:34.346Z                     -0.08133933288430695
# 999  2021-12-10T03:23:00.479Z                      0.08781463296772023
#
#      price_change_percentage_7d_in_currency
# 0                        -14.22282311402837
# 1                        -8.058433543569944
# 2                         -6.64440505615055
# 3                       0.20295697255838682
# 4                       -22.207433638951198
# ..                                      ...
# 995                     -23.882136619440914
# 996                     -0.5307132249264026
# 997                                     0.0
# 998                       72.51806995563392
# 999                      1.3957246119310858
#
# [1000 rows x 28 columns]

# %% [markdown]
# Our Pandas dataframe with 1000 coins!

# %%
for col in df:
    print(col)
# Out:
# id
# symbol
# name
# image
# current_price
# market_cap
# market_cap_rank
# fully_diluted_valuation
# total_volume
# high_24h
# low_24h
# price_change_24h
# price_change_percentage_24h
# market_cap_change_24h
# market_cap_change_percentage_24h
# circulating_supply
# total_supply
# max_supply
# ath
# ath_change_percentage
# ath_date
# atl
# atl_change_percentage
# atl_date
# roi
# last_updated
# price_change_percentage_24h_in_currency
# price_change_percentage_7d_in_currency

# %%
df.shape
# Out:
# (1000, 28)

# %% [markdown]
# Getting rid of scientific notation

# %%
pd.set_option('display.float_format', str)
df
# Out:
#                   id  symbol             name  \
# 0            bitcoin     btc          Bitcoin
# 1           ethereum     eth         Ethereum
# 2        binancecoin     bnb     Binance Coin
# 3             tether    usdt           Tether
# 4             solana     sol           Solana
# ..               ...     ...              ...
# 995           pibble     pib           Pibble
# 996           draken     drk           Draken
# 997     nectar-token     nec           Nectar
# 998     etherrock-72  pebble    Etherrock #72
# 999  mirrored-google  mgoogl  Mirrored Google
#
#                                                  image  current_price  \
# 0    https://assets.coingecko.com/coins/images/1/la...        48471.0
# 1    https://assets.coingecko.com/coins/images/279/...        4155.24
# 2    https://assets.coingecko.com/coins/images/825/...         579.28
# 3    https://assets.coingecko.com/coins/images/325/...       0.999768
# 4    https://assets.coingecko.com/coins/images/4128...         180.92
# ..                                                 ...            ...
# 995  https://assets.coingecko.com/coins/images/2972...     0.00156062
# 996  https://assets.coingecko.com/coins/images/1575...     0.01879855
# 997  https://assets.coingecko.com/coins/images/3559...       0.115536
# 998  https://assets.coingecko.com/coins/images/1796...     0.00025237
# 999  https://assets.coingecko.com/coins/images/1364...         2961.6
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0    916676439150                1          1018707947174.0 28270596038.0
# 1    493586415595                2                      NaN 24070832561.0
# 2     97595424357                3            97595424357.0  2007815364.0
# 3     77180934430                4                      NaN 60269165356.0
# 4     55705620939                5                      NaN  1809924235.0
# ..            ...              ...                      ...           ...
# 995      18337115              996                      NaN       39357.0
# 996      18336932              997               84198721.0           0.0
# 997      18292367              998               71416803.0           0.0
# 998      18170414              999               18170414.0       2963.19
# 999      18162605             1000                      NaN      621085.0
#
#       high_24h  ...        ath  ath_change_percentage  \
# 0      50308.0  ...    69045.0              -29.74138
# 1      4407.44  ...    4878.26              -14.74185
# 2       607.33  ...     686.31              -15.42898
# 3         1.01  ...       1.32              -24.42195
# 4       191.93  ...     259.96              -30.27882
# ..         ...  ...        ...                    ...
# 995 0.00161959  ... 0.02623939              -94.04919
# 996 0.01887865  ... 0.04441833              -57.67838
# 997   0.115536  ...   0.666145              -82.65601
# 998 0.00025439  ... 0.00228217              -88.94179
# 999    2987.37  ...    3112.79               -4.82657
#
#                      ath_date        atl  atl_change_percentage  \
# 0    2021-11-10T14:24:11.849Z      67.81            71439.03206
# 1    2021-11-10T14:24:19.604Z   0.432979           960481.45801
# 2    2021-05-10T07:24:17.097Z  0.0398177          1457584.69949
# 3    2018-07-24T00:00:00.000Z   0.572521               74.66078
# 4    2021-11-06T21:54:35.825Z   0.500801            36091.33735
# ..                        ...        ...                    ...
# 995  2021-04-02T09:08:22.703Z  5.627e-05             2674.73595
# 996  2021-07-20T01:12:27.834Z 0.00701652               167.9186
# 997  2018-05-15T00:11:18.020Z 0.00102922            11125.63507
# 998  2021-10-24T07:48:52.955Z  3.129e-05              706.45931
# 999  2021-11-10T14:30:45.284Z    1654.63               79.04607
#
#                      atl_date  \
# 0    2013-07-06T00:00:00.000Z
# 1    2015-10-20T00:00:00.000Z
# 2    2017-10-19T00:00:00.000Z
# 3    2015-03-02T00:00:00.000Z
# 4    2020-05-11T19:35:23.449Z
# ..                        ...
# 995  2020-05-06T23:55:04.172Z
# 996  2021-06-01T11:25:41.506Z
# 997  2018-12-17T00:00:00.000Z
# 998  2021-08-30T10:43:31.102Z
# 999  2021-01-18T05:38:41.649Z
#
#                                                    roi  \
# 0                                                 None
# 1    {'times': 113.69423777357225, 'currency': 'btc...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995  {'times': -0.9248934563020185, 'currency': 'et...
# 996                                               None
# 997                                               None
# 998                                               None
# 999                                               None
#
#                  last_updated  price_change_percentage_24h_in_currency  \
# 0    2021-12-10T03:25:00.060Z                      -2.7924383263404384
# 1    2021-12-10T03:24:18.385Z                        -5.45337672861116
# 2    2021-12-10T03:25:40.240Z                       -4.047705974219436
# 3    2021-12-10T03:22:31.902Z                     -0.10801497173107566
# 4    2021-12-10T03:24:53.168Z                       -4.902930781530062
# ..                        ...                                      ...
# 995  2021-12-10T03:24:07.951Z                       -3.641464772998457
# 996  2021-12-10T03:18:49.179Z                     -0.31430650535809584
# 997  2021-12-10T03:18:46.561Z                                      0.0
# 998  2021-12-10T03:14:34.346Z                     -0.08133933288430695
# 999  2021-12-10T03:23:00.479Z                      0.08781463296772023
#
#      price_change_percentage_7d_in_currency
# 0                        -14.22282311402837
# 1                        -8.058433543569944
# 2                         -6.64440505615055
# 3                       0.20295697255838682
# 4                       -22.207433638951198
# ..                                      ...
# 995                     -23.882136619440914
# 996                     -0.5307132249264026
# 997                                     0.0
# 998                       72.51806995563392
# 999                      1.3957246119310858
#
# [1000 rows x 28 columns]

# %% [markdown]
# Here's my full data frame with all the columns I think are most relevent

# %%
coins=df[['symbol','name','market_cap','current_price','market_cap_rank','price_change_percentage_24h_in_currency','price_change_percentage_7d_in_currency']]
coins.head()
# Out:
#   symbol          name    market_cap  current_price  market_cap_rank  \
# 0    btc       Bitcoin  916676439150        48471.0                1
# 1    eth      Ethereum  493586415595        4155.24                2
# 2    bnb  Binance Coin   97595424357         579.28                3
# 3   usdt        Tether   77180934430       0.999768                4
# 4    sol        Solana   55705620939         180.92                5
#
#    price_change_percentage_24h_in_currency  \
# 0                      -2.7924383263404384
# 1                        -5.45337672861116
# 2                       -4.047705974219436
# 3                     -0.10801497173107566
# 4                       -4.902930781530062
#
#    price_change_percentage_7d_in_currency
# 0                      -14.22282311402837
# 1                      -8.058433543569944
# 2                       -6.64440505615055
# 3                     0.20295697255838682
# 4                     -22.207433638951198

# %% [markdown]
# ### Discarding the cryptocurrencies with NaN Values

# %%
coins.count()
# Out:
# symbol                                     1000
# name                                       1000
# market_cap                                 1000
# current_price                               998
# market_cap_rank                            1000
# price_change_percentage_24h_in_currency     990
# price_change_percentage_7d_in_currency      989
# dtype: int64

# %%
coins.isna().sum()
# Out:
# symbol                                      0
# name                                        0
# market_cap                                  0
# current_price                               2
# market_cap_rank                             0
# price_change_percentage_24h_in_currency    10
# price_change_percentage_7d_in_currency     11
# dtype: int64

# %%
coins[coins.isna().any(axis=1)]
# Out:
#     symbol                     name  market_cap  current_price  \
# 400   koge         BNB48 Club Token   127100662          63.43
# 466     gf                  GuildFi    96911227           2.24
# 468   obtc            BoringDAO BTC    96503441        48003.0
# 549    zai      Zero Collateral Dai    73529894     0.00091691
# 622   dust               DUST Token    54045048       0.222347
# 631   zpay                  ZoidPay    52736435            NaN
# 650  slink                    sLINK    49190525          33.52
# 683    hoo                Hoo Token    44511122            NaN
# 816    nex                     Nash    29428847           1.01
# 825   bpay                   BNBPay    28927656      0.0057437
# 908    col            Unit Protocol    23762600     0.00536966
# 952  steth  StakeHound Staked Ether    20832900          321.6
# 954     bz               BitZ Token    20646579       0.161305
#
#      market_cap_rank  price_change_percentage_24h_in_currency  \
# 400              401                      -2.5994559878450176
# 466              467                       -8.369093292766888
# 468              469                       -4.944451321361828
# 549              550                                      NaN
# 622              623                                      NaN
# 631              632                                      NaN
# 650              651                                      NaN
# 683              684                                      NaN
# 816              817                                      NaN
# 825              826                                      NaN
# 908              909                                      NaN
# 952              953                                      NaN
# 954              955                                      NaN
#
#      price_change_percentage_7d_in_currency
# 400                                     NaN
# 466                                     NaN
# 468                                     NaN
# 549                                     NaN
# 622                                     NaN
# 631                                     NaN
# 650                                     NaN
# 683                                     NaN
# 816                    -0.43026533811260914
# 825                     -13.651752249415509
# 908                                     NaN
# 952                                     NaN
# 954                                     NaN

# %%
coins=coins.dropna()
coins.shape
# Out:
# (987, 7)

# %%
coins.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### How big is Bitcoin compared with the rest of the cryptocurrencies?

# %%
def top_10():
    cap=coins[['name','market_cap']]
    TOP_CAP_TITLE = 'Top 10 market capitalization'
    TOP_CAP_YLABEL = '% of total cap'
    cap10=cap.sort_values('market_cap',ascending=False).iloc[0:10].set_index('name')
    return cap10
top_10()
# Out:
#                 market_cap
# name
# Bitcoin       916676439150
# Ethereum      493586415595
# Binance Coin   97595424357
# Tether         77180934430
# Solana         55705620939
# Cardano        41771155691
# USD Coin       40999068016
# XRP            40456750111
# Polkadot       29163312626
# Terra          25940106530

# %%
cap10=cap10.assign(percent_of_market = lambda x:x.market_cap/cap.market_cap.sum()*100)

# %%
def top_10_chart():
    top10=cap10.assign(percent_of_market = lambda x:x.market_cap/cap.market_cap.sum()*100)
    ax=top10.percent_of_market.plot.bar()
    ax.set_ylabel(TOP_CAP_YLABEL)
    ax.set_title(TOP_CAP_TITLE)
    return ax
top_10_chart()
# Out:
# <AxesSubplot:title={'center':'Top 10 market capitalization'}, xlabel='name', ylabel='% of total cap'>

# %%
colors = ['orange', 'green', 'orange', 'cyan', 'cyan', 'blue', 'silver', 'orange', 'red', 'green']
ax=cap10.market_cap.plot.bar(color=colors,logy=True)
ax.set_ylabel('USD')
ax.set_xlabel('')
ax.set_title('Top 10 market capitalization')
# Out:
# Text(0.5, 1.0, 'Top 10 market capitalization')

# %% [markdown]
# Bitcoin and Ethereum make up over 50 percent of the entire Cryptocurrency market!

# %% [markdown]
# ### What is going on? Volatility in cryptocurrencies

# %%
volatility=coins[['name','price_change_percentage_24h_in_currency']].set_index('name')
volatility =  volatility.sort_values('price_change_percentage_24h_in_currency',ascending=True)
volatility.head()
# Out:
#                   price_change_percentage_24h_in_currency
# name
# Stronghold Token                       -33.86258025673607
# Reddcoin                              -26.322601968947694
# Clearpool                             -25.481550552061528
# Ribbon Finance                        -23.246529724038577
# Opacity                               -22.852366786515688

# %% [markdown]
# Top 5 losers in the last 24 hours

# %%
volatility24=coins[['name','price_change_percentage_24h_in_currency']].set_index('name')
volatility24 =  volatility.sort_values('price_change_percentage_24h_in_currency',ascending=False)
volatility24.head()
# Out:
#                       price_change_percentage_24h_in_currency
# name
# Phoenix Global [OLD]                        5311.082392669528
# Mobius                                      335.5482720574321
# Veritaseum                                   96.6013642762148
# Circuits of Value                           60.67197600237779
# StackOS                                    56.728590175421424

# %% [markdown]
# Top 5 winners in the last 24 hours.

# %%
def top10_subplot(volatility_series, title):
    # making the subplot and the figure for nrows and ncolumns
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 6))
    # Plotting with pandas the barchart for the top 10 losers with the color RED
    ax = volatility_series[:10].plot.bar(color="darkred", ax=axes[0])
    # Setting the main title to TITLE
    fig.suptitle(title)
    # Setting the ylabel to "% change"
    ax.set_ylabel('24 hour % change')
    # Same as above, but for the top 10 winners and in darkblue
    ax = volatility_series[-10:].plot.bar(color="green", ax=axes[1])
    # Returning this for good practice, might use later
    return fig, ax

DTITLE = "24 Hour Top Losers and Winners"

# Calling the function above with the volatility.percent_change_24h series
# and title DTITLE 
top10_subplot(volatility.price_change_percentage_24h_in_currency, DTITLE)
# Out:
# (<Figure size 720x432 with 2 Axes>, <AxesSubplot:xlabel='name'>)

# %%
volatility2=coins[['name','price_change_percentage_7d_in_currency']].set_index('name')
volatility2 =  volatility2.sort_values('price_change_percentage_7d_in_currency',ascending=True)
volatility2.head()
def top10_subplot_7d(volatility_series, title):
    # making the subplot and the figure for nrows and ncolumns
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 6))
    # Plotting with pandas the barchart for the top 10 losers with the color RED
    ax = volatility2_series[:10].plot.bar(color="darkred", ax=axes[0])
    # Setting the main title to TITLE
    fig.suptitle(title)
    # Setting the ylabel to "% change"
    ax.set_ylabel('24 hour % change')
    # Same as above, but for the top 10 winners and in darkblue
    ax = volatility_series2[-10:].plot.bar(color="green", ax=axes[1])
    # Returning this for good practice, might use later
    return fig, ax

DTITLE = "7 Day Top Losers and Winners"

# Calling the function above with the volatility.percent_change_24h series
# and title DTITLE 
top10_subplot(volatility2.price_change_percentage_7d_in_currency, DTITLE)
# Out:
# (<Figure size 720x432 with 2 Axes>, <AxesSubplot:xlabel='name'>)

# %%
weekly_loss_coins=volatility2
weekly_loss_coins.loc[weekly_loss_coins.price_change_percentage_7d_in_currency >0].count()
#coins with gains in the last 7 days
# Out:
# price_change_percentage_7d_in_currency    112
# dtype: int64

# %%
weekly_loss_coins.loc[weekly_loss_coins.price_change_percentage_7d_in_currency <0].count()
#coins with losses in the last 7 days.
# Out:
# price_change_percentage_7d_in_currency    869
# dtype: int64

# %% [markdown]
# ### Most coins are tiny

# %%
large_caps=coins.loc[coins.market_cap>10000000000]
large_caps
# Out:
#    symbol             name    market_cap  current_price  market_cap_rank  \
# 0     btc          Bitcoin  916676439150        48471.0                1
# 1     eth         Ethereum  493586415595        4155.24                2
# 2     bnb     Binance Coin   97595424357         579.28                3
# 3    usdt           Tether   77180934430       0.999768                4
# 4     sol           Solana   55705620939         180.92                5
# 5     ada          Cardano   41771155691            1.3                6
# 6    usdc         USD Coin   40999068016         0.9984                7
# 7     xrp              XRP   40456750111       0.854199                8
# 8     dot         Polkadot   29163312626          27.39                9
# 9    luna            Terra   25940106530          68.32               10
# 10   doge         Dogecoin   22723012582        0.17141               11
# 11   AVAX        Avalanche   21719847601          89.29               12
# 12   shib        Shiba Inu   19349255586      3.517e-05               13
# 13  matic          Polygon   15347565285           2.23               14
# 14    cro  Crypto.com Coin   14681176588       0.580599               15
# 15   busd      Binance USD   13757141766       0.998786               16
# 16   wbtc  Wrapped Bitcoin   12438248252        48427.0               17
# 17    ltc         Litecoin   10653246943         153.89               18
#
#     price_change_percentage_24h_in_currency  \
# 0                       -2.7924383263404384
# 1                         -5.45337672861116
# 2                        -4.047705974219436
# 3                      -0.10801497173107566
# 4                        -4.902930781530062
# 5                          -5.3388205671938
# 6                       0.04240439917449024
# 7                      -0.15791175150261563
# 8                        -5.593860106655768
# 9                         -8.20518826652749
# 10                       -3.393274379965485
# 11                      -3.5929326548028473
# 12                       -4.058517003565595
# 13                       -5.166487639898205
# 14                       -4.908370923694112
# 15                     -0.10238752105116815
# 16                        -3.00990145768716
# 17                       -4.482696095992629
#
#     price_change_percentage_7d_in_currency
# 0                       -14.22282311402837
# 1                       -8.058433543569944
# 2                        -6.64440505615055
# 3                      0.20295697255838682
# 4                      -22.207433638951198
# 5                      -24.084479685405732
# 6                      0.02157773323887115
# 7                      -12.768320079443956
# 8                       -23.32136385417946
# 9                       3.8205979772662575
# 10                      -18.27198526899363
# 11                      -17.37995855837763
# 12                     -16.905617380928078
# 13                       4.827654640136006
# 14                     -15.753927530972595
# 15                  -0.0018944803926591895
# 16                     -14.431160061831305
# 17                     -24.426154489752328

# %% [markdown]
# **Coin Cap Breakdown**:
# * Large cap: +10 billion
# * Mid cap: 2 billion - 10 billion
# * Small cap: 300 million - 2 billion
# * Micro cap: 50 million - 300 million
# * Nano cap: Below 50 million

# %%
cap_type=coins[['name','market_cap']]
cap_type
# Out:
#                 name    market_cap
# 0            Bitcoin  916676439150
# 1           Ethereum  493586415595
# 2       Binance Coin   97595424357
# 3             Tether   77180934430
# 4             Solana   55705620939
# ..               ...           ...
# 995           Pibble      18337115
# 996           Draken      18336932
# 997           Nectar      18292367
# 998    Etherrock #72      18170414
# 999  Mirrored Google      18162605
#
# [987 rows x 2 columns]

# %%
cap_type['Market_Cap_Type']=np.where(
     cap_type['market_cap'].between(0, 50000000, inclusive=False), 
    'Nano', 
     np.where(
        cap_type['market_cap'].between(50000000, 300000000, inclusive=False), 'Micro',
    np.where(
        cap_type['market_cap'].between(300000000, 2000000000, inclusive=False), 'Small',
    np.where(
        cap_type['market_cap'].between(2000000000, 10000000000, inclusive=False), 'Mid','Large'
     
         
     )))
)
# Out:
# <ipython-input-235-4e0b44d90da4>:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   cap_type['market_cap'].between(0, 50000000, inclusive=False),
# <ipython-input-235-4e0b44d90da4>:5: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   cap_type['market_cap'].between(50000000, 300000000, inclusive=False), 'Micro',
# <ipython-input-235-4e0b44d90da4>:7: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   cap_type['market_cap'].between(300000000, 2000000000, inclusive=False), 'Small',
# <ipython-input-235-4e0b44d90da4>:9: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   cap_type['market_cap'].between(2000000000, 10000000000, inclusive=False), 'Mid','Large'
# <ipython-input-235-4e0b44d90da4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cap_type['Market_Cap_Type']=np.where(

# %%
cap_type.Market_Cap_Type.value_counts().plot(kind='barh')
plt.title('Coin Market Cap Share')
# Out:
# Text(0.5, 1.0, 'Coin Market Cap Share')

# %%
def perc(x):
    percent=x/984*100
    return percent
def market_pie_chart():
    percent_of_market = cap_type.Market_Cap_Type.value_counts().rename_axis('market_cap_type').reset_index(name='counts')
    percent_of_market['share_percentage']=percent_of_market.counts.apply(perc)
    plt.figure(figsize=(10,8))
    colors = sns.color_palette('pastel')[0:5]
    a=plt.pie(data=percent_of_market,x='share_percentage',colors=colors,autopct='%.0f%%',explode=(.1, .1, 0, 0,0),shadow=True )  
    plt.title('Most coins are tiny')
    plt.legend(percent_of_market['market_cap_type'])
    return a
market_pie_chart()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa5ffb6cd90>,
#   <matplotlib.patches.Wedge at 0x7fa5ffb7a700>,
#   <matplotlib.patches.Wedge at 0x7fa5ffb7afd0>,
#   <matplotlib.patches.Wedge at 0x7fa5ffb888e0>,
#   <matplotlib.patches.Wedge at 0x7fa5ffb951f0>],
#  [Text(0.34457050788892357, 1.1494655997867746, ''),
#   Text(-1.0363540846676396, -0.6049547182993942, ''),
#   Text(0.6094885114396983, -0.9157094268505818, ''),
#   Text(1.054178085149614, -0.31417919216633877, ''),
#   Text(1.0981950780458716, -0.06298865418328836, '')],
#  [Text(0.20099946293520538, 0.6705215998756184, '41%'),
#   Text(-0.6045398827227897, -0.35289025234131327, '35%'),
#   Text(0.33244827896710816, -0.4994778691912264, '17%'),
#   Text(0.5750062282634258, -0.17137046845436657, '6%'),
#   Text(0.5990154971159299, -0.03435744773633911, '2%')])

# %% [markdown]
# ### **Key Findings**

# %% [markdown]
# * **Bitcoin and Ethereum make up a major share of the market**. Bitcoin alone makes up around 48% of the entire Cryptocurrency Market.
#
#
#
#
#
# * **Crypto Currency is a very volatile asset**. Since I had live data through the use of the API, as I was working through some of the volatility charts I was seeing massive changes in percent change in just hours. At the time of writing this Phoenix Global OLD was up over 5000% in the last 24 hours followed by Mobius which is up over 300 % in 24 hours. Both Pheonix old and Mobis have market caps around 25 Million which makes them very volatile to any price movement in both directions which makes them very risky. These types of coins are also not seen on normal crypto exchanges like CoinBase due to their risk which makes them harder to buy as well. During my analysis the entire market took a crash so I was able to see some big losses in price as well. Stronghold token alone was down 33% in 24 hours as well as many others down 25% from the day before. Looking at the 7 Day chart, Starship and Euphoria were down over 60% in the last 7 days! Looking at all coins in the last 7 days, only 112 of the 1000 coins had posted gains in the last 7 days. As with any investing, there’s a big risk and reward situation there for people willing to take it. Look at this data a few weeks ago during a heavy bull ruin, the gains would have far out weight the losses!
#
#
#
#
#
# * **Most coins in the market are tiny regarding their market cap**. 76% of coins were considered Nano or Micro meaning their market cap was less than 300 Million. A few years ago that might have been a big market cap, but now with bitcoin hovering around 1 trillion dollars, the field has really widened.

# %% [markdown]
# ### Short Comings in Analysis

# %% [markdown]
# I would have liked to focus on a select group of the top coins on the market right now and build a price prediction model based on the Coin Gecko api data. I will be visiting this project in a few months to start working on building out these models after studying some more on what models for this would be best!
